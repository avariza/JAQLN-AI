# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Preprocessing

# %%
with open("Traffic_violations.csv", "r") as csv_file:
    headers = " ".join([line.strip() for line in csv_file.readlines()[:2]]).split(",")

df = pd.read_csv("Traffic_violations.csv", encoding="Latin-1", delimiter=",",
                   skiprows=1, header=None).iloc[:, 1:]
# Out:
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/2694403725.py:4: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Traffic_violations.csv", encoding="Latin-1", delimiter=",",

# %%
print(df.shape)
df.head(3)
# Out:
# (1859607, 42)
#            1         2    3                            4   \
# 0  05/01/2023  23:11:00  MCP  3rd District, Silver Spring
# 1  04/30/2023  23:55:00  MCP        4th District, Wheaton
# 2  04/30/2023  04:24:00  MCP       2nd District, Bethesda
#
#                                                   5   \
# 0    OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 1  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 2  NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
#
#                                  6          7          8   9   10  ...  \
# 0  BRIGGS CHANEY RD @ COLUMIBA PIKE   0.000000   0.000000  No  No  ...
# 1      KEMP MILL ROAD @ ALPERT LANE  39.053038 -77.024637  No  No  ...
# 2   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113  No  No  ...
#
#             33                      34     35     36 37             38  39  \
# 0   13-401(b1)  Transportation Article  False  WHITE  M   GAITHERSBURG  MD
# 1    13-401(h)  Transportation Article  False  WHITE  F  SILVER SPRING  MD
# 2  21-901.1(b)  Transportation Article  False  BLACK  F  SILVER SPRING  MD
#
#    40                 41                                     42
# 0  MD  A - Marked Patrol                             (0.0, 0.0)
# 1  MD  A - Marked Patrol  (39.0530383333333, -77.0246366666667)
# 2  MD  A - Marked Patrol          (38.99148, -77.0971133333333)
#
# [3 rows x 42 columns]

# %%
# 'SeqID',
df.columns=['Date_Of_Stop','Time_Of_Stop','Agency','SubAgency','Description','Location',
'Latitude','Longitude','Accident','Belts','Personal_Injury','Property_Damage','Fatal',
'Commercial_License','HAZMAT','Commercial_Vehicle','Alcohol','Work_Zone','Search_Conducted',
'Search_Disposition','Search_Outcome','Search_Reason','Search_Reason_For_Stop','Search_Type',
'Search_Arrest_Reason','State','VehicleType','Year','Make','Model','Color','Violation_Type',
'Charge','Article','Contributed_To_Accident','Race','Gender','Driver_City','Driver_State','DL_State', 
'Arrest_Type', 'Geolocation']

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Date_Of_Stop Time_Of_Stop Agency                    SubAgency  \
# 0   05/01/2023     23:11:00    MCP  3rd District, Silver Spring
# 1   04/30/2023     23:55:00    MCP        4th District, Wheaton
# 2   04/30/2023     04:24:00    MCP       2nd District, Bethesda
# 3   04/30/2023     04:24:00    MCP       2nd District, Bethesda
# 4   04/30/2023     04:24:00    MCP       2nd District, Bethesda
#
#                                          Description  \
# 0    OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 1  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 2  NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 3  RECKLESS DRIVING VEHICLE IN WANTON AND WILLFUL...
# 4  FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROAD...
#
#                            Location   Latitude  Longitude Accident Belts  \
# 0  BRIGGS CHANEY RD @ COLUMIBA PIKE   0.000000   0.000000       No    No
# 1      KEMP MILL ROAD @ ALPERT LANE  39.053038 -77.024637       No    No
# 2   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
# 3   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
# 4   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
#
#   Personal_Injury Property_Damage Fatal Commercial_License HAZMAT  \
# 0              No              No    No                 No     No
# 1              No              No    No                 No     No
# 2              No              No    No                 No     No
# 3              No              No    No                 No     No
# 4              No              No    No                 No     No
#
#   Commercial_Vehicle Alcohol Work_Zone Search_Conducted Search_Disposition  \
# 0                 No      No        No               No                NaN
# 1                 No      No        No               No                NaN
# 2                 No      No        No               No                NaN
# 3                 No      No        No               No                NaN
# 4                 No      No        No               No                NaN
#
#   Search_Outcome Search_Reason Search_Reason_For_Stop Search_Type  \
# 0       Citation           NaN             17-107(a1)         NaN
# 1       Citation           NaN                    55*         NaN
# 2       Citation           NaN              21-304(c)         NaN
# 3       Citation           NaN              21-304(c)         NaN
# 4       Citation           NaN              21-304(c)         NaN
#
#   Search_Arrest_Reason State      VehicleType    Year     Make   Model  Color  \
# 0                  NaN    MD  02 - Automobile  2007.0     CHEV    CRUZ  BLACK
# 1                  NaN    MD  02 - Automobile  2013.0  HYUNDAI  SONATA    RED
# 2                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
# 3                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
# 4                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
#
#   Violation_Type       Charge                 Article  \
# 0       Citation   13-401(b1)  Transportation Article
# 1       Citation    13-401(h)  Transportation Article
# 2       Citation  21-901.1(b)  Transportation Article
# 3       Citation  21-901.1(a)  Transportation Article
# 4       Citation    21-301(a)  Transportation Article
#
#    Contributed_To_Accident   Race Gender    Driver_City Driver_State DL_State  \
# 0                    False  WHITE      M   GAITHERSBURG           MD       MD
# 1                    False  WHITE      F  SILVER SPRING           MD       MD
# 2                    False  BLACK      F  SILVER SPRING           MD       MD
# 3                    False  BLACK      F  SILVER SPRING           MD       MD
# 4                    False  BLACK      F  SILVER SPRING           MD       MD
#
#          Arrest_Type                            Geolocation
# 0  A - Marked Patrol                             (0.0, 0.0)
# 1  A - Marked Patrol  (39.0530383333333, -77.0246366666667)
# 2  A - Marked Patrol          (38.99148, -77.0971133333333)
# 3  A - Marked Patrol          (38.99148, -77.0971133333333)
# 4  A - Marked Patrol          (38.99148, -77.0971133333333)

# %% [markdown]
# ## Cleaning and transforming

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859607 entries, 0 to 1859606
# Data columns (total 42 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Date_Of_Stop             object
#  1   Time_Of_Stop             object
#  2   Agency                   object
#  3   SubAgency                object
#  4   Description              object
#  5   Location                 object
#  6   Latitude                 float64
#  7   Longitude                float64
#  8   Accident                 object
#  9   Belts                    object
#  10  Personal_Injury          object
#  11  Property_Damage          object
#  12  Fatal                    object
#  13  Commercial_License       object
#  14  HAZMAT                   object
#  15  Commercial_Vehicle       object
#  16  Alcohol                  object
#  17  Work_Zone                object
#  18  Search_Conducted         object
#  19  Search_Disposition       object
#  20  Search_Outcome           object
#  21  Search_Reason            object
#  22  Search_Reason_For_Stop   object
#  23  Search_Type              object
#  24  Search_Arrest_Reason     object
#  25  State                    object
#  26  VehicleType              object
#  27  Year                     float64
#  28  Make                     object
#  29  Model                    object
#  30  Color                    object
#  31  Violation_Type           object
#  32  Charge                   object
#  33  Article                  object
#  34  Contributed_To_Accident  bool
#  35  Race                     object
#  36  Gender                   object
#  37  Driver_City              object
#  38  Driver_State             object
#  39  DL_State                 object
#  40  Arrest_Type              object
#  41  Geolocation              object
# dtypes: bool(1), float64(3), object(38)
# memory usage: 583.5+ MB

# %%
data = df.copy()
del data['Geolocation']
data['Date_Of_Stop'] = pd.to_datetime(data['Date_Of_Stop'])
data['Time_Of_Stop'] = pd.to_datetime(data['Time_Of_Stop'], format='%H:%M:%S').dt.time
data['Day_of_Week'] = data['Date_Of_Stop'].dt.day_name()
data['Hour_of_Day'] = data['Time_Of_Stop'].apply(lambda x: x.hour)
pd.set_option('display.max_columns', None)
data.head()
# Out:
#   Date_Of_Stop Time_Of_Stop Agency                    SubAgency  \
# 0   2023-05-01     23:11:00    MCP  3rd District, Silver Spring
# 1   2023-04-30     23:55:00    MCP        4th District, Wheaton
# 2   2023-04-30     04:24:00    MCP       2nd District, Bethesda
# 3   2023-04-30     04:24:00    MCP       2nd District, Bethesda
# 4   2023-04-30     04:24:00    MCP       2nd District, Bethesda
#
#                                          Description  \
# 0    OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 1  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 2  NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 3  RECKLESS DRIVING VEHICLE IN WANTON AND WILLFUL...
# 4  FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROAD...
#
#                            Location   Latitude  Longitude Accident Belts  \
# 0  BRIGGS CHANEY RD @ COLUMIBA PIKE   0.000000   0.000000       No    No
# 1      KEMP MILL ROAD @ ALPERT LANE  39.053038 -77.024637       No    No
# 2   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
# 3   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
# 4   JONES MILL ROAD/ LE VELLE DRIVE  38.991480 -77.097113       No    No
#
#   Personal_Injury Property_Damage Fatal Commercial_License HAZMAT  \
# 0              No              No    No                 No     No
# 1              No              No    No                 No     No
# 2              No              No    No                 No     No
# 3              No              No    No                 No     No
# 4              No              No    No                 No     No
#
#   Commercial_Vehicle Alcohol Work_Zone Search_Conducted Search_Disposition  \
# 0                 No      No        No               No                NaN
# 1                 No      No        No               No                NaN
# 2                 No      No        No               No                NaN
# 3                 No      No        No               No                NaN
# 4                 No      No        No               No                NaN
#
#   Search_Outcome Search_Reason Search_Reason_For_Stop Search_Type  \
# 0       Citation           NaN             17-107(a1)         NaN
# 1       Citation           NaN                    55*         NaN
# 2       Citation           NaN              21-304(c)         NaN
# 3       Citation           NaN              21-304(c)         NaN
# 4       Citation           NaN              21-304(c)         NaN
#
#   Search_Arrest_Reason State      VehicleType    Year     Make   Model  Color  \
# 0                  NaN    MD  02 - Automobile  2007.0     CHEV    CRUZ  BLACK
# 1                  NaN    MD  02 - Automobile  2013.0  HYUNDAI  SONATA    RED
# 2                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
# 3                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
# 4                  NaN    MD  02 - Automobile  2019.0   NISSAN  ALTIMA   GRAY
#
#   Violation_Type       Charge                 Article  \
# 0       Citation   13-401(b1)  Transportation Article
# 1       Citation    13-401(h)  Transportation Article
# 2       Citation  21-901.1(b)  Transportation Article
# 3       Citation  21-901.1(a)  Transportation Article
# 4       Citation    21-301(a)  Transportation Article
#
#    Contributed_To_Accident   Race Gender    Driver_City Driver_State DL_State  \
# 0                    False  WHITE      M   GAITHERSBURG           MD       MD
# 1                    False  WHITE      F  SILVER SPRING           MD       MD
# 2                    False  BLACK      F  SILVER SPRING           MD       MD
# 3                    False  BLACK      F  SILVER SPRING           MD       MD
# 4                    False  BLACK      F  SILVER SPRING           MD       MD
#
#          Arrest_Type Day_of_Week  Hour_of_Day
# 0  A - Marked Patrol      Monday           23
# 1  A - Marked Patrol      Sunday           23
# 2  A - Marked Patrol      Sunday            4
# 3  A - Marked Patrol      Sunday            4
# 4  A - Marked Patrol      Sunday            4

# %%
# Too heavy for my pc
"""
data[['Arrest_Category', 'Arrest_Description']] = data['Arrest_Type'].apply(lambda x: pd.Series(str(x).split(" - ")))
data[['Vehicle_Category', 'Vehicle_Type']] = data['VehicleType'].apply(lambda x: pd.Series(str(x).split(" - ")))
"""
# Out:
# '\ndata[[\'Arrest_Category\', \'Arrest_Description\']] = data[\'Arrest_Type\'].apply(lambda x: pd.Series(str(x).split(" - ")))\ndata[[\'Vehicle_Category\', \'Vehicle_Type\']] = data[\'VehicleType\'].apply(lambda x: pd.Series(str(x).split(" - ")))\n'

# %% [markdown]
# ## Duplicates

# %%
data.loc[data.duplicated(), :]
# Out:
#         Date_Of_Stop Time_Of_Stop Agency  \
# 2265      2023-05-11     08:20:00    MCP
# 2266      2023-05-11     08:20:00    MCP
# 16472     2014-06-07     20:42:00    MCP
# 19035     2012-01-20     13:23:00    MCP
# 22329     2020-06-25     12:12:00    MCP
# ...              ...          ...    ...
# 1840250   2012-08-31     15:12:00    MCP
# 1842673   2012-02-23     10:31:00    MCP
# 1842886   2012-04-05     22:08:00    MCP
# 1847309   2012-08-31     15:12:00    MCP
# 1849017   2021-04-22     04:35:00    MCP
#
#                                                SubAgency  \
# 2265                              2nd District, Bethesda
# 2266                              2nd District, Bethesda
# 16472                              4th District, Wheaton
# 19035                            1st District, Rockville
# 22329    6th District, Gaithersburg / Montgomery Village
# ...                                                  ...
# 1840250                           2nd District, Bethesda
# 1842673                           2nd District, Bethesda
# 1842886                          1st District, Rockville
# 1847309                           2nd District, Bethesda
# 1849017  6th District, Gaithersburg / Montgomery Village
#
#                                                Description  \
# 2265     DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2266     DISPLAYING EXPIRED REGISTRATION PLATE ISSUED B...
# 16472    FAILURE MOTOR VEH. DRIVER TO FURNISH WRITTEN I...
# 19035    DRIVING/ATTEMPTING DRIVE MOTOR VEH. ON HWY W/O...
# 22329    FAIL OF DRIVER IN ATTEND VEH ACCIDENT TO FURNI...
# ...                                                    ...
# 1840250                                        Stop Lights
# 1842673  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 1842886  FAILURE TO PROPERLY EQUIP & LOCATE HEADLAMPS O...
# 1847309                                         Taillights
# 1849017  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
#
#                                     Location   Latitude  Longitude Accident  \
# 2265               HILLCREST ST/ROSEMARY CIR  38.977375 -77.080544       No
# 2266               HILLCREST ST/ROSEMARY CIR  38.977375 -77.080544       No
# 16472          2303 GEORGIAN WAY, WHEATON MD  39.058958 -77.049192       No
# 19035       NELSON  ST/ WOODLEY GARDENS PARK  39.091862 -77.173584       No
# 22329                   SHADY GROVE RD @ 355  39.154040 -77.211366      Yes
# ...                                      ...        ...        ...      ...
# 1840250            RTE 121/GATEWAY CENTER DR  39.236653 -77.283049       No
# 1842673  MAC ARTHUR BLVD @ UNION ARCH BRIDGE  38.972809 -77.147364       No
# 1842886              TWINBROOK PKWY/ARDENNES  39.065394 -77.115215       No
# 1847309            RTE 121/GATEWAY CENTER DR  39.236653 -77.283049       No
# 1849017        WATKINS MILL RD @ I270 S RAMP   0.000000   0.000000       No
#
#         Belts Personal_Injury Property_Damage Fatal Commercial_License HAZMAT  \
# 2265       No              No              No    No                 No     No
# 2266       No              No              No    No                 No     No
# 16472      No              No             Yes    No                 No     No
# 19035      No              No              No    No                 No     No
# 22329      No              No              No    No                 No     No
# ...       ...             ...             ...   ...                ...    ...
# 1840250    No              No              No    No                 No     No
# 1842673    No              No              No    No                 No     No
# 1842886    No              No              No    No                 No     No
# 1847309    No              No              No    No                 No     No
# 1849017    No              No              No    No                 No     No
#
#         Commercial_Vehicle Alcohol Work_Zone Search_Conducted  \
# 2265                    No      No        No               No
# 2266                    No      No        No               No
# 16472                   No      No        No               No
# 19035                   No      No        No              NaN
# 22329                   No      No        No              NaN
# ...                    ...     ...       ...              ...
# 1840250                 No      No        No              NaN
# 1842673                Yes      No        No              NaN
# 1842886                 No      No        No              NaN
# 1847309                 No      No        No              NaN
# 1849017                 No      No        No               No
#
#         Search_Disposition Search_Outcome Search_Reason  \
# 2265                   NaN        Warning           NaN
# 2266                   NaN        Warning           NaN
# 16472                  NaN       Citation           NaN
# 19035                  NaN            NaN           NaN
# 22329                  NaN            NaN           NaN
# ...                    ...            ...           ...
# 1840250                NaN            NaN           NaN
# 1842673                NaN            NaN           NaN
# 1842886                NaN            NaN           NaN
# 1847309                NaN            NaN           NaN
# 1849017                NaN        Warning           NaN
#
#         Search_Reason_For_Stop Search_Type Search_Arrest_Reason State  \
# 2265                21-201(a1)         NaN                  NaN    DC
# 2266                21-201(a1)         NaN                  NaN    DC
# 16472               21-902(a1)         NaN                  NaN    MD
# 19035                      NaN         NaN                  NaN    MD
# 22329                      NaN         NaN                  NaN    MD
# ...                        ...         ...                  ...   ...
# 1840250                    NaN         NaN                  NaN    MD
# 1842673                    NaN         NaN                  NaN    MD
# 1842886                    NaN         NaN                  NaN    MD
# 1847309                    NaN         NaN                  NaN    MD
# 1849017              21-204(d)         NaN                  NaN    MD
#
#                    VehicleType    Year   Make    Model   Color Violation_Type  \
# 2265           02 - Automobile  2018.0  BUICK      SUV    GRAY        Warning
# 2266           02 - Automobile  2018.0  BUICK      SUV    GRAY        Warning
# 16472          02 - Automobile  2006.0  CHEVY    TRUCK   WHITE       Citation
# 19035          02 - Automobile  2011.0   CHEV   CAMERY    GRAY       Citation
# 22329          02 - Automobile  2017.0  ACURA       TK   BLACK       Citation
# ...                        ...     ...    ...      ...     ...            ...
# 1840250  05 - Light Duty Truck  2009.0   CHEV      BOX   WHITE           SERO
# 1842673  05 - Light Duty Truck  1999.0   CHEV       TK   WHITE        Warning
# 1842886        02 - Automobile  2003.0    TOY  COROLLA  MAROON        Warning
# 1847309  05 - Light Duty Truck  2009.0   CHEV      BOX   WHITE           SERO
# 1849017        02 - Automobile  2003.0  HONDA    CIVIC     RED        Warning
#
#              Charge                 Article  Contributed_To_Accident  \
# 2265     21-201(a1)  Transportation Article                    False
# 2266      13-411(f)  Transportation Article                    False
# 16472     20-105(c)  Transportation Article                    False
# 19035     16-101(a)  Transportation Article                    False
# 22329     20-104(b)  Transportation Article                     True
# ...             ...                     ...                      ...
# 1840250         64*                     NaN                    False
# 1842673  21-201(a1)  Transportation Article                    False
# 1842886   22-203(b)  Transportation Article                    False
# 1847309         56*                     NaN                    False
# 1849017  21-201(a1)  Transportation Article                    False
#
#              Race Gender   Driver_City Driver_State DL_State  \
# 2265        WHITE      F    WASHINGTON           DC       DC
# 2266        WHITE      F    WASHINGTON           DC       DC
# 16472    HISPANIC      M       WHEATON           MD       MD
# 19035       BLACK      M       POTOMAC           MD       MD
# 22329       WHITE      M    BROOKVILLE           MD       MD
# ...           ...    ...           ...          ...      ...
# 1840250     WHITE      M  WALKERSVILLE           MD       MD
# 1842673     WHITE      M         JOPPA           MD       MD
# 1842886     BLACK      F   TAKOMA PARK           MD       MD
# 1847309     WHITE      M  WALKERSVILLE           MD       MD
# 1849017  HISPANIC      M  GAITHERSBURG           MD       MD
#
#                Arrest_Type Day_of_Week  Hour_of_Day
# 2265     A - Marked Patrol    Thursday            8
# 2266     A - Marked Patrol    Thursday            8
# 16472    A - Marked Patrol    Saturday           20
# 19035    A - Marked Patrol      Friday           13
# 22329    A - Marked Patrol    Thursday           12
# ...                    ...         ...          ...
# 1840250  A - Marked Patrol      Friday           15
# 1842673  A - Marked Patrol    Thursday           10
# 1842886  A - Marked Patrol    Thursday           22
# 1847309  A - Marked Patrol      Friday           15
# 1849017  A - Marked Patrol    Thursday            4
#
# [2228 rows x 43 columns]

# %%
data.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# ## Missing values

# %%
percent_missing = data.isnull().sum() * 100 / len(df)
percent_missing.sort_values(ascending=False)
# Out:
# Search_Arrest_Reason       96.833417
# Search_Type                95.422796
# Search_Reason              95.422420
# Search_Disposition         95.422420
# Search_Outcome             38.901123
# Search_Reason_For_Stop     37.881284
# Search_Conducted           37.866926
# Article                     4.594143
# Color                       1.152286
# Year                        0.554418
# DL_State                    0.049957
# Driver_City                 0.023338
# Model                       0.011454
# Make                        0.003657
# State                       0.003173
# Driver_State                0.000592
# Description                 0.000538
# Location                    0.000215
# Personal_Injury             0.000000
# Date_Of_Stop                0.000000
# Belts                       0.000000
# Accident                    0.000000
# Longitude                   0.000000
# Latitude                    0.000000
# SubAgency                   0.000000
# Time_Of_Stop                0.000000
# Agency                      0.000000
# VehicleType                 0.000000
# Property_Damage             0.000000
# Commercial_License          0.000000
# Fatal                       0.000000
# HAZMAT                      0.000000
# Commercial_Vehicle          0.000000
# Alcohol                     0.000000
# Work_Zone                   0.000000
# Contributed_To_Accident     0.000000
# Charge                      0.000000
# Violation_Type              0.000000
# Gender                      0.000000
# Race                        0.000000
# Arrest_Type                 0.000000
# Day_of_Week                 0.000000
# Hour_of_Day                 0.000000
# dtype: float64

# %%
data.Search_Arrest_Reason.value_counts(normalize=True) * 100
# Out:
# Search_Arrest_Reason
# Stop         63.563839
# Search       19.961877
# Other        11.228776
# Warrant       5.164319
# Traffic       0.040594
# DUI           0.022945
# Marihuana     0.008825
# Criminal      0.005295
# DWI           0.003530
# Name: proportion, dtype: float64

# %%
print('Search_Arrest_Reason: ',data.Search_Arrest_Reason.unique())
print('Search_Reason: ', data.Search_Reason.unique())
print('search type: ', data.Search_Type.unique())
print('HAZMAT: ', data.HAZMAT.unique())
# Out:
# Search_Arrest_Reason:  [nan 'Stop' 'Warrant' 'Search' 'Other' 'DUI' 'DWI' 'Traffic' 'Marihuana'
#  'Criminal']
# Search_Reason:  [nan 'Incident to Arrest' 'Consensual' 'Probable Cause' 'K-9' 'Other'
#  'Exigent Circumstances' 'Arrest/Tow' 'Probable Cause for CDS'
#  'plain view marijuana' 'DUI']
# search type:  [nan 'Both' 'Property' 'Person' 'Search Incidental' 'car' 'PC']
# HAZMAT:  ['No' 'Yes']

# %% [markdown]
# ## General EDA

# %%
#What are the most common types of traffic violations?

violation_distribution = data['Violation_Type'].value_counts()
violation_distribution.plot(kind='barh', color='skyblue')
plt.title('Most Common Types of Traffic Violations')
plt.xlabel('Number of Violations')
plt.ylabel('Violation Type')
plt.show()

# %%
# Are there any annual trend in traffic violations? 

violation_by_date = data.groupby(data['Date_Of_Stop'].dt.date)['Violation_Type'].count()
violation_by_date.plot(kind='line', marker='o', color='green')
plt.title('Annual Trend in Traffic Violations')
plt.xlabel('Date')
plt.ylabel('Number of Violations')
plt.grid(True)
plt.show()

# %%
#is there a particular day when violations are more frequent?

plt.figure(figsize=(12, 6))
sns.countplot(x='Day_of_Week', data=data, order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], palette='viridis')
plt.title('Traffic Violations by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Violations')
plt.show()
# Out:
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/1597356467.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Day_of_Week', data=data, order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], palette='viridis')

# %%
#is there a particular time when violations are more frequent?

heatmap_data = data.groupby(['Day_of_Week', 'Hour_of_Day']).size().unstack()
plt.figure(figsize=(15, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt='g')
plt.title('Violations by Day of the Week and Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')
plt.show()

# %%
# Which locations have the highest frequency of traffic violations?

top_locations = data['Location'].value_counts().head(10)
sns.barplot(x=top_locations.values, y=top_locations.index, palette='viridis')
plt.title('Top Locations with Highest Frequency of Traffic Violations')
plt.xlabel('Number of Violations')
plt.ylabel('Location')
plt.show()
# Out:
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/1351151458.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_locations.values, y=top_locations.index, palette='viridis')

# %%
# Are there any race disparities in traffic violations? 

race_distribution = data['Race'].value_counts()
print(race_distribution)

plt.figure(figsize=(12, 6))
sns.countplot(x='Race', data=data, palette='Set1')
plt.title('Distribution of Traffic Violations by Race')
plt.xlabel('Race')
plt.ylabel('Number of Violations')
plt.show()
# Out:
# Race
# WHITE              633377
# BLACK              591728
# HISPANIC           410301
# OTHER              113203
# ASIAN              105419
# NATIVE AMERICAN      3351
# Name: count, dtype: int64
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/1582014403.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Race', data=data, palette='Set1')

# %%
# Are there any gender disparities in traffic violations? 

gender_distribution = data['Gender'].value_counts()
print(gender_distribution)

plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=data, palette='pastel')
plt.title('Distribution of Traffic Violations by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Violations')
plt.show()
# Out:
# Gender
# M    1249707
# F     604849
# U       2823
# Name: count, dtype: int64
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/856179284.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=data, palette='pastel')

# %%
# Relation between both feaatures

plt.figure(figsize=(15, 8))
sns.countplot(x='Race', data=data, hue='Gender')
plt.title('Distribution of Races by Gender')
plt.show()

# %%
# What is the proportion of traffic stops where searches are conducted?

search_conducted_ratio = data['Search_Conducted'].value_counts(normalize=True)
print(search_conducted_ratio)

plt.figure(figsize=(10, 5))
sns.barplot(x=search_conducted_ratio.index, y=search_conducted_ratio.values * 100, palette='Blues')
plt.title('Proportion of Traffic Stops with Searches Conducted')
plt.xlabel('Search Conducted')
plt.ylabel('Percentage')
plt.show()
# Out:
# Search_Conducted
# No     0.928116
# Yes    0.071884
# Name: proportion, dtype: float64
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/4173664862.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=search_conducted_ratio.index, y=search_conducted_ratio.values * 100, palette='Blues')

# %%
# How often do traffic violations contribute to accidents?

accident_contribution = data['Contributed_To_Accident'].value_counts()
print(accident_contribution)

plt.figure(figsize=(8, 5))
sns.countplot(x='Contributed_To_Accident', data=df, palette='rocket')
plt.title('Frequency of Traffic Violations Contributing to Accidents')
plt.xlabel('Contribution to Accident')
plt.ylabel('Number of Violations')
plt.show()
# Out:
# Contributed_To_Accident
# False    1807134
# True       50245
# Name: count, dtype: int64
# /var/folders/q2/k9xdm7wn3_7cpc75plnlzl640000gn/T/ipykernel_42842/2483469839.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Contributed_To_Accident', data=df, palette='rocket')

# %%
# what are the common types of arrests?

common_arrest_types = data['Arrest_Type'].value_counts().head(10)
print(common_arrest_types)

plt.figure(figsize=(12, 6))
common_arrest_types.plot(kind='bar', color='orange')
plt.title('Common Types of Arrests')
plt.xlabel('Arrest Type')
plt.ylabel('Number of Arrests')
plt.show()
# Out:
# Arrest_Type
# A - Marked Patrol                       1510307
# Q - Marked Laser                         175560
# B - Unmarked Patrol                       73708
# S - License Plate Recognition             16235
# G - Marked Moving Radar (Stationary)      16226
# L - Motorcycle                            15894
# O - Foot Patrol                           14610
# E - Marked Stationary Radar               13193
# R - Unmarked Laser                         8054
# M - Marked (Off-Duty)                      4432
# Name: count, dtype: int64

# %%
# What are the most common charges associated with traffic violations?
common_charges = data['Charge'].value_counts().head(10)
print(common_charges)


plt.figure(figsize=(12, 6))
common_charges.head(10).plot(kind='bar', color='coral')
plt.title('Most Common Charges Associated with Traffic Violations')
plt.xlabel('Charge')
plt.ylabel('Number of Violations')
plt.show()
# Out:
# Charge
# 21-801.1         247971
# 21-201(a1)       154928
# 13-409(b)         84234
# 21-707(a)         58282
# 13-401(h)         55414
# 16-112(c)         49161
# 13-411(f)         47471
# 21-1124.2(d2)     45150
# 16-303(c)         35828
# 16-303(h)         34090
# Name: count, dtype: int64

# %% [markdown]
# ### Numerical columns

# %%
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
data[numerical_cols].hist(bins=3, figsize=(15, 5))
plt.suptitle('Histograms of Numerical Features', y=1)
plt.show()

# %% [markdown]
# ### categorical columns

# %%
categorical_cols = data.select_dtypes(include=['object']).columns

short_columns = []

for col in categorical_cols:
    if data[col].nunique() < 11:
        short_columns.append(col)                               
    else:
       pass

print(short_columns)
# Out:
# ['Agency', 'SubAgency', 'Accident', 'Belts', 'Personal_Injury', 'Property_Damage', 'Fatal', 'Commercial_License', 'HAZMAT', 'Commercial_Vehicle', 'Alcohol', 'Work_Zone', 'Search_Conducted', 'Search_Disposition', 'Search_Outcome', 'Search_Reason', 'Search_Type', 'Search_Arrest_Reason', 'Violation_Type', 'Article', 'Race', 'Gender', 'Day_of_Week']

# %%
short_categotical = data[short_columns]#.apply(lambda x: x.value_counts(normalize=True) * 100)
short_categotical.isnull().sum()
# Out:
# Agency                        0
# SubAgency                     0
# Accident                      0
# Belts                         0
# Personal_Injury               0
# Property_Damage               0
# Fatal                         0
# Commercial_License            0
# HAZMAT                        0
# Commercial_Vehicle            0
# Alcohol                       0
# Work_Zone                     0
# Search_Conducted         704176
# Search_Disposition      1774482
# Search_Outcome           723408
# Search_Reason           1774482
# Search_Type             1774489
# Search_Arrest_Reason    1800721
# Violation_Type                0
# Article                   85433
# Race                          0
# Gender                        0
# Day_of_Week                   0
# dtype: int64

# %%
# Relationship between 'Search_Conducted' and 'Search_Outcome'

plt.figure(figsize=(10, 6))
sns.countplot(x='Search_Conducted', data=data, hue='Search_Outcome')
plt.title('Relationship between Search Conducted and Outcome')
plt.show()

# %% [markdown]
# ### Some Lat Long analysis

# %%
zero_lat = data[data.Latitude == 0.000000]
print('Percentage of zeros: ',len(zero_lat)/len(data)*100)
print(zero_lat.shape)
print(zero_lat.Accident.unique())
print(zero_lat.Longitude.unique())
zero_lat.head()
# Out:
# Percentage of zeros:  6.915174555112339
# (128441, 43)
# ['No' 'Yes']
# [0.         0.01666667]
#    Date_Of_Stop Time_Of_Stop Agency                    SubAgency  \
# 0    2023-05-01     23:11:00    MCP  3rd District, Silver Spring
# 9    2023-04-30     10:43:00    MCP  3rd District, Silver Spring
# 10   2023-04-30     10:43:00    MCP  3rd District, Silver Spring
# 11   2023-04-30     10:43:00    MCP  3rd District, Silver Spring
# 12   2023-04-30     10:43:00    MCP  3rd District, Silver Spring
#
#                                           Description  \
# 0     OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 9   PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...
# 10     DISPLAYING REG. PLATE ISSUED FOR OTHER VEHICLE
# 11  DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A...
# 12                KNOWINGLY DRIVING UNINSURED VEHICLE
#
#                             Location  Latitude  Longitude Accident Belts  \
# 0   BRIGGS CHANEY RD @ COLUMIBA PIKE       0.0        0.0       No    No
# 9                 650 AT LOCKWOOD DR       0.0        0.0       No   Yes
# 10                650 AT LOCKWOOD DR       0.0        0.0       No   Yes
# 11                650 AT LOCKWOOD DR       0.0        0.0       No   Yes
# 12                650 AT LOCKWOOD DR       0.0        0.0       No   Yes
#
#    Personal_Injury Property_Damage Fatal Commercial_License HAZMAT  \
# 0               No              No    No                 No     No
# 9               No              No    No                 No     No
# 10              No              No    No                 No     No
# 11              No              No    No                 No     No
# 12              No              No    No                 No     No
#
#    Commercial_Vehicle Alcohol Work_Zone Search_Conducted Search_Disposition  \
# 0                  No      No        No               No                NaN
# 9                  No      No        No               No                NaN
# 10                 No      No        No               No                NaN
# 11                 No      No        No               No                NaN
# 12                 No      No        No               No                NaN
#
#    Search_Outcome Search_Reason Search_Reason_For_Stop Search_Type  \
# 0        Citation           NaN             17-107(a1)         NaN
# 9        Citation           NaN              13-411(g)         NaN
# 10       Citation           NaN              13-411(g)         NaN
# 11       Citation           NaN              13-411(g)         NaN
# 12       Citation           NaN              13-411(g)         NaN
#
#    Search_Arrest_Reason State      VehicleType    Year    Make   Model  Color  \
# 0                   NaN    MD  02 - Automobile  2007.0    CHEV    CRUZ  BLACK
# 9                   NaN    XX  02 - Automobile  2002.0  NISSAN  MAXIMA   GRAY
# 10                  NaN    XX  02 - Automobile  2002.0  NISSAN  MAXIMA   GRAY
# 11                  NaN    XX  02 - Automobile  2002.0  NISSAN  MAXIMA   GRAY
# 12                  NaN    XX  02 - Automobile  2002.0  NISSAN  MAXIMA   GRAY
#
#    Violation_Type      Charge                 Article  \
# 0        Citation  13-401(b1)  Transportation Article
# 9        Citation   16-303(c)  Transportation Article
# 10       Citation   13-411(g)  Transportation Article
# 11       Citation   16-303(h)  Transportation Article
# 12       Citation  17-107(a1)  Transportation Article
#
#     Contributed_To_Accident   Race Gender    Driver_City Driver_State  \
# 0                     False  WHITE      M   GAITHERSBURG           MD
# 9                     False  BLACK      M  SILVER SPRING           MD
# 10                    False  BLACK      M  SILVER SPRING           MD
# 11                    False  BLACK      M  SILVER SPRING           MD
# 12                    False  BLACK      M  SILVER SPRING           MD
#
#    DL_State        Arrest_Type Day_of_Week  Hour_of_Day
# 0        MD  A - Marked Patrol      Monday           23
# 9        MD  A - Marked Patrol      Sunday           10
# 10       MD  A - Marked Patrol      Sunday           10
# 11       MD  A - Marked Patrol      Sunday           10
# 12       MD  A - Marked Patrol      Sunday           10

# %%
data.isnull().sum()
# Out:
# Date_Of_Stop                     0
# Time_Of_Stop                     0
# Agency                           0
# SubAgency                        0
# Description                     10
# Location                         4
# Latitude                         0
# Longitude                        0
# Accident                         0
# Belts                            0
# Personal_Injury                  0
# Property_Damage                  0
# Fatal                            0
# Commercial_License               0
# HAZMAT                           0
# Commercial_Vehicle               0
# Alcohol                          0
# Work_Zone                        0
# Search_Conducted            704176
# Search_Disposition         1774482
# Search_Outcome              723408
# Search_Reason              1774482
# Search_Reason_For_Stop      704443
# Search_Type                1774489
# Search_Arrest_Reason       1800721
# State                           59
# VehicleType                      0
# Year                         10310
# Make                            68
# Model                          213
# Color                        21428
# Violation_Type                   0
# Charge                           0
# Article                      85433
# Contributed_To_Accident          0
# Race                             0
# Gender                           0
# Driver_City                    434
# Driver_State                    11
# DL_State                       929
# Arrest_Type                      0
# Day_of_Week                      0
# Hour_of_Day                      0
# dtype: int64

# %%
data.nunique()
# Out:
# Date_Of_Stop                 4172
# Time_Of_Stop                 1440
# Agency                          1
# SubAgency                       9
# Description                 16201
# Location                   245591
# Latitude                   339743
# Longitude                  383063
# Accident                        2
# Belts                           2
# Personal_Injury                 2
# Property_Damage                 2
# Fatal                           2
# Commercial_License              2
# HAZMAT                          2
# Commercial_Vehicle              2
# Alcohol                         2
# Work_Zone                       2
# Search_Conducted                2
# Search_Disposition              7
# Search_Outcome                  5
# Search_Reason                  10
# Search_Reason_For_Stop        794
# Search_Type                     6
# Search_Arrest_Reason            9
# State                          71
# VehicleType                    33
# Year                          397
# Make                         4540
# Model                       21788
# Color                          26
# Violation_Type                  4
# Charge                       1141
# Article                         5
# Contributed_To_Accident         2
# Race                            6
# Gender                          3
# Driver_City                  8825
# Driver_State                   68
# DL_State                       72
# Arrest_Type                    19
# Day_of_Week                     7
# Hour_of_Day                    24
# dtype: int64

# %%
data.to_csv('./data.csv',index=False)
